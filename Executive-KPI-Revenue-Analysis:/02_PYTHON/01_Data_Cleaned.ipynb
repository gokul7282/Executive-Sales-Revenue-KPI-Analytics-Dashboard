# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f7e1ff9e-1b50-451f-b810-31a6af1b153a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7e1ff9e-1b50-451f-b810-31a6af1b153a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'superstore raw.csv', 'sample_data']

# %%
df=pd.read_csv('superstore raw.csv')

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Record_Count', 'Order.Date', 'Order.ID',
#        'Order.Priority', 'Product.ID', 'Product.Name', 'Profit', 'Quantity',
#        'Region', 'Row.ID', 'Sales', 'Segment', 'Ship.Date', 'Ship.Mode',
#        'Shipping.Cost', 'State', 'Sub.Category', 'Year', 'Market2', 'weeknum',
#        'Month', 'Month_Name', 'quarter', 'ShippingDays', 'Profit_Margin'],
#       dtype='object')

# %%
df.rename(columns={
    "记录数":"Record_Count"
}, inplace=True)

# %%
df.head(20)
# Out:
#            Category         City        Country Customer.ID  \
# 0   Office Supplies  Los Angeles  United States   LS-172304
# 1   Office Supplies  Los Angeles  United States   MV-174854
# 2   Office Supplies  Los Angeles  United States   CS-121304
# 3   Office Supplies  Los Angeles  United States   CS-121304
# 4   Office Supplies  Los Angeles  United States   AP-109154
# 5   Office Supplies  Los Angeles  United States   JF-154904
# 6   Office Supplies  Los Angeles  United States   WB-218504
# 7   Office Supplies  Los Angeles  United States   JA-159704
# 8   Office Supplies  Los Angeles  United States   SP-209204
# 9   Office Supplies  Los Angeles  United States   RL-196154
# 10  Office Supplies  Los Angeles  United States   KD-163454
# 11  Office Supplies  Los Angeles  United States   JM-161954
# 12  Office Supplies  Los Angeles  United States   JM-161954
# 13  Office Supplies  Los Angeles  United States   RD-195854
# 14  Office Supplies  Los Angeles  United States   AB-101654
# ...

# %%
#check the missing values
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
#check the duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
#DataType Convesion
df['Order.Date']=pd.to_datetime(df['Order.Date'])
df['Ship.Date']=pd.to_datetime(df['Ship.Date'])

# %%
#column clean up
df.columns=df.columns.str.strip()

# %%
#Feature Engineering
df['Month']=df['Order.Date'].dt.month
df['Month_Name']=df['Order.Date'].dt.month_name()
df['quarter']=df['Order.Date'].dt.quarter
df['ShippingDays']=(df['Ship.Date']-df['Order.Date']).dt.days
df['Profit_Margin']=(df['Profit'] / df['Sales']) * 100

# %%
df[['Month','Month_Name','quarter','Profit_Margin']]
# Out:
#        Month Month_Name  quarter  Profit_Margin
# 0          1    January        1      49.111579
# 1          1    January        1      48.909474
# 2          8     August        3      46.865714
# 3          8     August        3      47.982703
# 4          9  September        3      51.840000
# ...      ...        ...      ...            ...
# 51285     12   December        4      32.714783
# 51286     12   December        4      35.093333
# 51287     12   December        4      35.670000
# 51288     12   December        4      37.700000
# 51289     12   December        4      33.651818
#
# [51290 rows x 4 columns]

# %%
#save cleaned data
df.to_csv('cleaned.csv',index=False)

# %%
df.to_csv(
    "sales_mysql.csv",
    index=False,
    encoding="utf-8-sig"
)

# %%
from google.colab import files
files.download('cleaned.csv')

# %% [markdown]
# # Data Cleaning Summary
#
# The Global Superstore dataset was cleaned and prepared for analysis.
#
# Cleaning activities performed:
#
# 1. Removed leading and trailing spaces from column names.
# 2. Checked for missing values and handled them appropriately.
# 3. Checked for duplicate records.
# 4. Converted date columns to datetime format.
# 5. Created additional date-related columns such as Year, Month, and Quarter.
# 6. Verified data types for numerical and categorical fields.
# 7. Standardized column formatting where required.
# 8. Exported the cleaned dataset for SQL analysis, EDA, and dashboard development.
#
# Outcome:
#
# The dataset is now clean, consistent, and ready for further analysis and visualization.

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...
